# %%
import pandas as pd
from string import ascii_uppercase as alphabet
import pickle

# %%
all_tables = pd.read_html('https://web.archive.org/web/202211115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup')

# %%
all_tables [12]
# Out:
#    Pos  \
# 0    1
# 1    2
# 2    3
# 3    4
#
#   Team.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte  \
# 0                                          Qatar (H)
# 1                                            Ecuador
# 2                                            Senegal
# 3                                        Netherlands
#
#    Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    0  0  0  0   0   0   0    0                        NaN
# 3    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables [19]
# Out:
#    Pos        Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
# 0    1        England    0  0  0  0   0   0   0    0
# 1    2           Iran    0  0  0  0   0   0   0    0
# 2    3  United States    0  0  0  0   0   0   0    0
# 3    4          Wales    0  0  0  0   0   0   0    0
#
#                Qualification
# 0  Advance to knockout stage
# 1  Advance to knockout stage
# 2                        NaN
# 3                        NaN

# %%
all_tables [26]
# Out:
#    Pos       Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1     Argentina    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2  Saudi Arabia    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3        Mexico    0  0  0  0   0   0   0    0                        NaN
# 3    4        Poland    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables [33]
# Out:
#    Pos    Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1     France    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2  Australia    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3    Denmark    0  0  0  0   0   0   0    0                        NaN
# 3    4    Tunisia    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables [40]
# Out:
#    Pos     Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1       Spain    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2  Costa Rica    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3     Germany    0  0  0  0   0   0   0    0                        NaN
# 3    4       Japan    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables [47]
# Out:
#    Pos  Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1  Belgium    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2   Canada    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3  Morocco    0  0  0  0   0   0   0    0                        NaN
# 3    4  Croatia    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables [54]
# Out:
#    Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1       Brazil    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2       Serbia    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3  Switzerland    0  0  0  0   0   0   0    0                        NaN
# 3    4     Cameroon    0  0  0  0   0   0   0    0                        NaN

# %%
all_tables [61]
# Out:
#    Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1     Portugal    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2        Ghana    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3      Uruguay    0  0  0  0   0   0   0    0                        NaN
# 3    4  South Korea    0  0  0  0   0   0   0    0                        NaN

# %%
alphabet
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
all_tables [12].columns[1]
# Out:
# 'Team.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte'

# %%
dict_table = {}
for letter, i in zip(alphabet, range(12, 68, 7)):
    df = all_tables [i]
    df.rename(columns = {df.columns[1]: 'Team'}, inplace = True)
    df.pop('Qualification')
    dict_table[f'Group {letter}'] = df

# %%
dict_table.keys()
# Out:
# dict_keys(['Group A', 'Group B', 'Group C', 'Group D', 'Group E', 'Group F', 'Group G', 'Group H'])

# %%
dict_table['Group A']
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0
# 1    2      Ecuador    0  0  0  0   0   0   0    0
# 2    3      Senegal    0  0  0  0   0   0   0    0
# 3    4  Netherlands    0  0  0  0   0   0   0    0

# %%
dict_table['Group B']
# Out:
#    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1        England    0  0  0  0   0   0   0    0
# 1    2           Iran    0  0  0  0   0   0   0    0
# 2    3  United States    0  0  0  0   0   0   0    0
# 3    4          Wales    0  0  0  0   0   0   0    0

# %%
dict_table['Group C']
# Out:
#    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     Argentina    0  0  0  0   0   0   0    0
# 1    2  Saudi Arabia    0  0  0  0   0   0   0    0
# 2    3        Mexico    0  0  0  0   0   0   0    0
# 3    4        Poland    0  0  0  0   0   0   0    0

# %%
dict_table['Group D']
# Out:
#    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     France    0  0  0  0   0   0   0    0
# 1    2  Australia    0  0  0  0   0   0   0    0
# 2    3    Denmark    0  0  0  0   0   0   0    0
# 3    4    Tunisia    0  0  0  0   0   0   0    0

# %%
dict_table['Group E']
# Out:
#    Pos        Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1       Spain    0  0  0  0   0   0   0    0
# 1    2  Costa Rica    0  0  0  0   0   0   0    0
# 2    3     Germany    0  0  0  0   0   0   0    0
# 3    4       Japan    0  0  0  0   0   0   0    0

# %%
dict_table['Group F']
# Out:
#    Pos     Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1  Belgium    0  0  0  0   0   0   0    0
# 1    2   Canada    0  0  0  0   0   0   0    0
# 2    3  Morocco    0  0  0  0   0   0   0    0
# 3    4  Croatia    0  0  0  0   0   0   0    0

# %%
dict_table['Group G']
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1       Brazil    0  0  0  0   0   0   0    0
# 1    2       Serbia    0  0  0  0   0   0   0    0
# 2    3  Switzerland    0  0  0  0   0   0   0    0
# 3    4     Cameroon    0  0  0  0   0   0   0    0

# %%
dict_table['Group H']
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     Portugal    0  0  0  0   0   0   0    0
# 1    2        Ghana    0  0  0  0   0   0   0    0
# 2    3      Uruguay    0  0  0  0   0   0   0    0
# 3    4  South Korea    0  0  0  0   0   0   0    0

# %%
with open('wc22_groups.csv', 'wb') as output:
    pickle.dump(dict_table, output)

# %%
groups_df_file = open("wc22_groups.csv", "rb")
groups = pickle.load(groups_df_file)
groups_df_file.close()
print(groups)
# Out:
# {'Group A':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0
# 1    2      Ecuador    0  0  0  0   0   0   0    0
# 2    3      Senegal    0  0  0  0   0   0   0    0
# 3    4  Netherlands    0  0  0  0   0   0   0    0, 'Group B':    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1        England    0  0  0  0   0   0   0    0
# 1    2           Iran    0  0  0  0   0   0   0    0
# 2    3  United States    0  0  0  0   0   0   0    0
# 3    4          Wales    0  0  0  0   0   0   0    0, 'Group C':    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     Argentina    0  0  0  0   0   0   0    0
# 1    2  Saudi Arabia    0  0  0  0   0   0   0    0
# 2    3        Mexico    0  0  0  0   0   0   0    0
# 3    4        Poland    0  0  0  0   0   0   0    0, 'Group D':    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     France    0  0  0  0   0   0   0    0
# 1    2  Australia    0  0  0  0   0   0   0    0
# 2    3    Denmark    0  0  0  0   0   0   0    0
# 3    4    Tunisia    0  0  0  0   0   0   0    0, 'Group E':    Pos        Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1       Spain    0  0  0  0   0   0   0    0
# 1    2  Costa Rica    0  0  0  0   0   0   0    0
# 2    3     Germany    0  0  0  0   0   0   0    0
# 3    4       Japan    0  0  0  0   0   0   0    0, 'Group F':    Pos     Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1  Belgium    0  0  0  0   0   0   0    0
# 1    2   Canada    0  0  0  0   0   0   0    0
# 2    3  Morocco    0  0  0  0   0   0   0    0
# 3    4  Croatia    0  0  0  0   0   0   0    0, 'Group G':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1       Brazil    0  0  0  0   0   0   0    0
# 1    2       Serbia    0  0  0  0   0   0   0    0
# 2    3  Switzerland    0  0  0  0   0   0   0    0
# 3    4     Cameroon    0  0  0  0   0   0   0    0, 'Group H':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     Portugal    0  0  0  0   0   0   0    0
# 1    2        Ghana    0  0  0  0   0   0   0    0
# 2    3      Uruguay    0  0  0  0   0   0   0    0
# 3    4  South Korea    0  0  0  0   0   0   0    0}
